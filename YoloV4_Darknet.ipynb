# %%
import os
import glob
import xml.etree.ElementTree as ET
from shutil import copyfile
import argparse
from pathlib import Path
import random
import matplotlib.pyplot as plt

# %%
root_path = '/home/lsunku/ds/Thesis/rdd'

# %%
os.chdir(root_path)

# %%
# !pwd
# Out:
# /home/lsunku/ds/Thesis/rdd

# %%
# %cd data/yolo_txt/orig
# Out:
# /home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig

# %%
#generate path of test file

yolo_train = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/train/images/*.jpg")
yolo_valid = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/valid/images/*.jpg")
yolo_test = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/test/images/*.jpg")
print(len(yolo_train))
print(len(yolo_valid))
print(len(yolo_test))


im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_train_data", "w")
for i in range(len(yolo_train)):
    im_file_hndl.writelines(yolo_train[i] + "\n")
im_file_hndl.close()

im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_valid_data", "w")
for i in range(len(yolo_valid)):
    im_file_hndl.writelines(yolo_valid[i] + "\n")
im_file_hndl.close()

im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_data", "w")
for i in range(len(yolo_test)):
    im_file_hndl.writelines(yolo_test[i] + "\n")
im_file_hndl.close()
# Out:
# 10152
# 1026
# 1017

# %%
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_train_data /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_valid_data /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_data /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data

# %%
#generate path of test file

yolo_jap = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/test/images/Japan*.jpg")
yolo_ind = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/test/images/India*.jpg")
yolo_cze = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/test/images/Czech*.jpg")
print(len(yolo_jap))
print(len(yolo_ind))
print(len(yolo_cze))


im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_jap", "w")
for i in range(len(yolo_jap)):
    im_file_hndl.writelines(yolo_jap[i] + "\n")
im_file_hndl.close()

im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_ind", "w")
for i in range(len(yolo_ind)):
    im_file_hndl.writelines(yolo_ind[i] + "\n")
im_file_hndl.close()

im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_cze", "w")
for i in range(len(yolo_cze)):
    im_file_hndl.writelines(yolo_cze[i] + "\n")
im_file_hndl.close()
# Out:
# 655
# 276
# 86

# %%
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_jap /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_ind /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/yolo_test_cze /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data

# %% [markdown]
# ## Modelling on Original Data

# %%
# %cd /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet
# Out:
# /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet

# %%
./darknet detector train data/yolov4.data cfg/yolov4-rdd.cfg yolov4.conv.137 -dont_show -map
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    256 x 256 x   3 ->  256 x 256 x  32 0.113 BF
#    1 conv     64       3 x 3/ 2    256 x 256 x  32 ->  128 x 128 x  64 0.604 BF
#    2 conv     64       1 x 1/ 1    128 x 128 x  64 ->  128 x 128 x  64 0.134 BF
#    3 route  1 		                           ->  128 x 128 x  64
#    4 conv     64       1 x 1/ 1    128 x 128 x  64 ->  128 x 128 x  64 0.134 BF
#    5 conv     32       1 x 1/ 1    128 x 128 x  64 ->  128 x 128 x  32 0.067 BF
#    6 conv     64       3 x 3/ 1    128 x 128 x  32 ->  128 x 128 x  64 0.604 BF
# ...

# %%
import os
from sklearn.model_selection import train_test_split

import os
import xml.etree.ElementTree as ET
from shutil import copyfile
import argparse
from pathlib import Path
import random
import matplotlib.pyplot as plt

# %%
# %cd /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet
# Out:
# /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet

# %%
# %cp data/yolov4_test.data cfg/coco.data

# %%
def imShow(path):
    import cv2
    import matplotlib.pyplot as plt
    # %matplotlib inline
    
    image = cv2.imread(path)
    height, width = image.shape[:2]
    resized_image = cv2.resize(image,(3*width,3*height), interpolation = cv2.INTER_CUBIC)
    
    fig = plt.gcf()
    fig.set_size_inches(18,10)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(resized_image,cv2.COLOR_BGR2RGB))
    plt.show()

# %%
test_img_path = "/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/test/images"
test_images = [test_img_path+ '/' + f for f in os.listdir(test_img_path) if f.endswith(".jpg")]
test_img_path =  random.choice(test_images)
test_img_path
# Out:
# '/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/test/images/Japan_000211_jpg.rf.4cd8ed04d7fc52da1a99af0a0a3d6877.jpg'

# %%
#! ./darknet detect cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights {random.choice(test_images)} -dont-show

! ./darknet detect cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights /home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/test/images/India_003565_jpg.rf.574d454010cb7f7b3d872a5a371ea4e0.jpg
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# Cannot load image data/labels/53_0.png
# ...

# %%
fig = plt.figure(figsize=(12,12))
plt.axis(False)
plt.imshow(plt.imread("./predictions.jpg"))

# %%
#to get map - test data
#! ./darknet detector map data/yolov4_test.data cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights

# %%
fig = plt.figure(figsize=(12,12))
plt.axis(False)
plt.imshow(plt.imread("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/orig/test/images/Japan_012420_jpg.rf.216a13f54fcd5700b3f6aa7e5f6876d6.jpg"))

# %% [markdown]
# ### Check the model on validation data

# %%
# %cp data/yolov4.data cfg/coco.data

# %%
#to get map - validation data
! ./darknet detector map cfg/coco.data cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    544 x 544 x   3 ->  544 x 544 x  32 0.511 BF
#    1 conv     64       3 x 3/ 2    544 x 544 x  32 ->  272 x 272 x  64 2.727 BF
#    2 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    3 route  1 		                           ->  272 x 272 x  64
#    4 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    5 conv     32       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  32 0.303 BF
#    6 conv     64       3 x 3/ 1    272 x 272 x  32 ->  272 x 272 x  64 2.727 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 272 x 272 x  64 0.005 BF
# ...

# %% [markdown]
# ### Check the model on test data

# %%
# %cp data/yolov4_test.data cfg/coco.data

# %%
# to write to results.txt
#! ./darknet detector test cfg/coco.data cfg/yolov4-rdd_test.cfg backup/original_data/yolov4-rdd_best.weights -dont_show -ext_output <data/rdd_test_1> result.txt
# generation of results
! ./darknet detector map cfg/coco.data cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    544 x 544 x   3 ->  544 x 544 x  32 0.511 BF
#    1 conv     64       3 x 3/ 2    544 x 544 x  32 ->  272 x 272 x  64 2.727 BF
#    2 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    3 route  1 		                           ->  272 x 272 x  64
#    4 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    5 conv     32       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  32 0.303 BF
#    6 conv     64       3 x 3/ 1    272 x 272 x  32 ->  272 x 272 x  64 2.727 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 272 x 272 x  64 0.005 BF
# ...

# %% [markdown]
# ### Check the model on Japan test data

# %%
# %cp data/yolov4_jap.data cfg/coco.data

# %%
#to get map - test data
! ./darknet detector map data/yolov4_jap.data cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    544 x 544 x   3 ->  544 x 544 x  32 0.511 BF
#    1 conv     64       3 x 3/ 2    544 x 544 x  32 ->  272 x 272 x  64 2.727 BF
#    2 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    3 route  1 		                           ->  272 x 272 x  64
#    4 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    5 conv     32       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  32 0.303 BF
#    6 conv     64       3 x 3/ 1    272 x 272 x  32 ->  272 x 272 x  64 2.727 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 272 x 272 x  64 0.005 BF
# ...

# %% [markdown]
# ### Check the model on India test data

# %%
# %cp data/yolov4_ind.data cfg/coco.data

# %%
#to get map - test data
! ./darknet detector map data/yolov4_ind.data cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    544 x 544 x   3 ->  544 x 544 x  32 0.511 BF
#    1 conv     64       3 x 3/ 2    544 x 544 x  32 ->  272 x 272 x  64 2.727 BF
#    2 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    3 route  1 		                           ->  272 x 272 x  64
#    4 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    5 conv     32       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  32 0.303 BF
#    6 conv     64       3 x 3/ 1    272 x 272 x  32 ->  272 x 272 x  64 2.727 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 272 x 272 x  64 0.005 BF
# ...

# %% [markdown]
# ### Check the model on Czech test data

# %%
# %cp data/yolov4_cze.data cfg/coco.data

# %%
#to get map - test data
! ./darknet detector map data/yolov4_cze.data cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    544 x 544 x   3 ->  544 x 544 x  32 0.511 BF
#    1 conv     64       3 x 3/ 2    544 x 544 x  32 ->  272 x 272 x  64 2.727 BF
#    2 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    3 route  1 		                           ->  272 x 272 x  64
#    4 conv     64       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  64 0.606 BF
#    5 conv     32       1 x 1/ 1    272 x 272 x  64 ->  272 x 272 x  32 0.303 BF
#    6 conv     64       3 x 3/ 1    272 x 272 x  32 ->  272 x 272 x  64 2.727 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 272 x 272 x  64 0.005 BF
# ...

# %% [markdown]
# ## Modelling on Augmentation

# %%
# %cd /home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug
# Out:
# /home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug

# %%
#generate path of test file

yolo_train_aug = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/train/images/*.jpg")
yolo_valid_aug = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/valid/images/*.jpg")
yolo_test_aug = glob.glob("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/test/images/*.jpg")
print(len(yolo_train_aug))
print(len(yolo_valid_aug))
print(len(yolo_test_aug))


im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/yolo_train_data_aug", "w")
for i in range(len(yolo_train_aug)):
    im_file_hndl.writelines(yolo_train_aug[i] + "\n")
im_file_hndl.close()

im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/yolo_valid_data_aug", "w")
for i in range(len(yolo_valid_aug)):
    im_file_hndl.writelines(yolo_valid_aug[i] + "\n")
im_file_hndl.close()

im_file_hndl = open("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/yolo_test_data_aug", "w")
for i in range(len(yolo_test_aug)):
    im_file_hndl.writelines(yolo_test_aug[i] + "\n")
im_file_hndl.close()
# Out:
# 20102
# 1084
# 1060

# %%
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/yolo_train_data_aug /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/yolo_valid_data_aug /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data
# !cp /home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/yolo_test_data_aug /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet/data

# %%
/darknet detector train data/yolov4_aug.data cfg/yolov4-rdd_aug.cfg backup/yolov4-rdd_aug_last.weights -dont_show -map

# %%
test_img_path = "/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/test/images"
test_images = [test_img_path+ '/' + f for f in os.listdir(test_img_path) if f.endswith(".jpg")]
test_img_path =  random.choice(test_images)
test_img_path
# Out:
# '/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/test/images/Japan_002940_jpg.rf.a836e35aee75f14422fd07381b696043.jpg'

# %%
# %cd /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet
# Out:
# /home/lsunku/ds/Thesis/rdd/yolo_v4/darknet

# %%
! ./darknet detect cfg/yolov4-rdd_test.cfg backup/yolov4-rdd_aug_best.weights {random.choice(test_images)} -dont-show
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# Cannot load image data/labels/53_0.png
# ...

# %%
fig = plt.figure(figsize=(12,12))
plt.axis(False)
plt.imshow(plt.imread("./predictions.jpg"))

# %%
fig = plt.figure(figsize=(12,12))
plt.axis(False)
plt.imshow(plt.imread("/home/lsunku/ds/Thesis/rdd/data/yolo_txt/aug/test/images/India_003565_jpg.rf.574d454010cb7f7b3d872a5a371ea4e0.jpg"))

# %% [markdown]
# ### Check the model on validation data

# %%
# %cp data/yolov4_aug.data cfg/coco.data

# %%
#to get map - validation data
! ./darknet detector map data/yolov4_aug.data cfg/yolov4-rdd_test_aug.cfg backup/yolov4-rdd_aug_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    512 x 512 x   3 ->  512 x 512 x  32 0.453 BF
#    1 conv     64       3 x 3/ 2    512 x 512 x  32 ->  256 x 256 x  64 2.416 BF
#    2 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    3 route  1 		                           ->  256 x 256 x  64
#    4 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    5 conv     32       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  32 0.268 BF
#    6 conv     64       3 x 3/ 1    256 x 256 x  32 ->  256 x 256 x  64 2.416 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 256 x 256 x  64 0.004 BF
# ...

# %% [markdown]
# ### Check the model on test data

# %%
# %cp data/yolov4_test_aug.data cfg/coco.data

# %%
#to get map - test data
! ./darknet detector map data/yolov4_test_aug.data cfg/yolov4-rdd_test_aug.cfg backup/yolov4-rdd_aug_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    512 x 512 x   3 ->  512 x 512 x  32 0.453 BF
#    1 conv     64       3 x 3/ 2    512 x 512 x  32 ->  256 x 256 x  64 2.416 BF
#    2 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    3 route  1 		                           ->  256 x 256 x  64
#    4 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    5 conv     32       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  32 0.268 BF
#    6 conv     64       3 x 3/ 1    256 x 256 x  32 ->  256 x 256 x  64 2.416 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 256 x 256 x  64 0.004 BF
# ...

# %% [markdown]
# ### Check the model on Japan test data

# %%
# %cp data/yolov4_jap.data cfg/coco.data

# %%
#to get map - test data
! ./darknet detector map data/yolov4_jap.data cfg/yolov4-rdd_test_aug.cfg backup/yolov4-rdd_aug_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    512 x 512 x   3 ->  512 x 512 x  32 0.453 BF
#    1 conv     64       3 x 3/ 2    512 x 512 x  32 ->  256 x 256 x  64 2.416 BF
#    2 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    3 route  1 		                           ->  256 x 256 x  64
#    4 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    5 conv     32       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  32 0.268 BF
#    6 conv     64       3 x 3/ 1    256 x 256 x  32 ->  256 x 256 x  64 2.416 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 256 x 256 x  64 0.004 BF
# ...

# %% [markdown]
# ### Check the model on India test data

# %%
# %cp data/yolov4_ind.data cfg/coco.data

# %%
#to get map - test data
! ./darknet detector map data/yolov4_ind.data cfg/yolov4-rdd_test_aug.cfg backup/yolov4-rdd_aug_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    512 x 512 x   3 ->  512 x 512 x  32 0.453 BF
#    1 conv     64       3 x 3/ 2    512 x 512 x  32 ->  256 x 256 x  64 2.416 BF
#    2 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    3 route  1 		                           ->  256 x 256 x  64
#    4 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    5 conv     32       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  32 0.268 BF
#    6 conv     64       3 x 3/ 1    256 x 256 x  32 ->  256 x 256 x  64 2.416 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 256 x 256 x  64 0.004 BF
# ...

# %% [markdown]
# ### Check the model on Czech test data

# %%
# %cp data/yolov4_cze.data cfg/coco.data

# %%
#to get map - test data
! ./darknet detector map data/yolov4_cze.data cfg/yolov4-rdd_test_aug.cfg backup/yolov4-rdd_aug_best.weights
# Out:
#  CUDA-version: 11000 (11000), cuDNN: 8.0.3, GPU count: 1
#  OpenCV version: 4.4.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: GeForce RTX 2070 SUPER
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    512 x 512 x   3 ->  512 x 512 x  32 0.453 BF
#    1 conv     64       3 x 3/ 2    512 x 512 x  32 ->  256 x 256 x  64 2.416 BF
#    2 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    3 route  1 		                           ->  256 x 256 x  64
#    4 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    5 conv     32       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  32 0.268 BF
#    6 conv     64       3 x 3/ 1    256 x 256 x  32 ->  256 x 256 x  64 2.416 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 256 x 256 x  64 0.004 BF
# ...
